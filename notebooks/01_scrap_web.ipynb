# %%
import time
import sys
sys.path.append("../")
from src import soporte_scrap_web as spc

# %%
df_todos_productos2 = await spc.main()

# %%
df_todos_productos2['precio'] = df_todos_productos2['precio'].str.replace(',', '.').astype(float)
df_todos_productos2.to_csv("../data/productos.csv")

# %%
df_todos_productos2
# Out:
#              fecha  precio Variacion  id_supermercado  id_categoria  \
# 0       12/07/2024    1.45         =                1             1
# 1       13/07/2024    1.45         =                1             1
# 2       14/07/2024    1.45         =                1             1
# 3       15/07/2024    1.45         =                1             1
# 4       16/07/2024    1.45         =                1             1
# ...            ...     ...       ...              ...           ...
# 137783  23/10/2024    4.73         =                6             3
# 137784  24/10/2024    4.73         =                6             3
# 137785  25/10/2024    4.73         =                6             3
# 137786  26/10/2024    4.73         =                6             3
# 137787  27/10/2024    4.73         =                6             3
#
#                                                  producto
# 0             aceite de girasol refinado 02 hacendado 1 l
# ...
